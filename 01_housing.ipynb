# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
#import seaborn as sns
import pandas as pd
import numpy as np
plt.rcParams['figure.dpi'] = 100

# %%
housing = pd.read_csv("housing.csv")

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.shape
# Out:
# (20640, 10)

# %%
housing.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
continuous_dependent = housing.columns[:-2]

# %%
housing[continuous_dependent].hist(bins="auto")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
housing.population.sort_values().tail()
# Out:
# 6057     15507.0
# 10309    16122.0
# 13139    16305.0
# 9880     28566.0
# 15360    35682.0
# Name: population, dtype: float64

# %%
# your solution here
housing.plot.hexbin(x='longitude',y='latitude',
            C='population', cmap='viridis',linewidth=0,reduce_C_function=np.sum)
# Out:
# <img src="data:image/png;base64,..." width="640">
